# %%
import numpy as np
import matplotlib.pyplot as plt
import os

current_dir = os.getcwd()
print(current_dir)

os.chdir("../topology_code")
parameter_dir = os.getcwd()
print(parameter_dir)

#os.chdir?
os.chdir(current_dir)
# Out:
# /home/lila/MD/topology_code
# /home/lila/MD
